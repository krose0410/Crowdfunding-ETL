# %%
# Import the Pandas dependency.
import pandas as pd

# %%
# Read the contacts string data into a Pandas DataFrame
contacts_string_df = pd.read_csv("contacts_string_data.csv")
contacts_string_df.head()
# Out:
#   contact_info  Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0  contact_id         4661      name    Cecilia
# 1  contact_id         3765      name    Mariana
# 2  contact_id         4187      name    Sofie Wo
# 3  contact_id         4941      name    Jeanette
# 4  contact_id         2199      name    Samuel S
#
#                                     Unnamed: 4
# 0   Velasco email cecilia.velasco@rodrigues.fr
# 1          Ellis email mariana.ellis@rossi.org
# 2            ods email sofie.woods@riviere.com
# 3   Iannotti email jeanette.iannotti@yahoo.com
# 4        orgatz email samuel.sorgatz@gmail.com

# %%
# Extract the four-digit contact ID number.
contacts_string_df['contact_id'] = contacts_string_df['contact_info'].str.extract(r'(\d{4})')
contacts_string_df
# Out:
#     contact_info  Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0    contact_id         4661      name    Cecilia
# 1    contact_id         3765      name    Mariana
# 2    contact_id         4187      name    Sofie Wo
# 3    contact_id         4941      name    Jeanette
# 4    contact_id         2199      name    Samuel S
# ..           ...         ...        ...        ...
# 995  contact_id         3684      name    Whitney
# 996  contact_id         5784      name    Gelsomin
# 997  contact_id         1498      name    Evangeli
# 998  contact_id         6073      name    Gareth C
# 999  contact_id         4939      name    Michelan
#
#                                             Unnamed: 4 contact_id
# 0           Velasco email cecilia.velasco@rodrigues.fr        NaN
# 1                  Ellis email mariana.ellis@rossi.org        NaN
# 2                    ods email sofie.woods@riviere.com        NaN
# 3           Iannotti email jeanette.iannotti@yahoo.com        NaN
# 4                orgatz email samuel.sorgatz@gmail.com        NaN
# ..                                                 ...        ...
# 995         Noack email whitney.noack@laboratorios.org        NaN
# 996   a Migliaccio email gelsomina.migliaccio@junk.com        NaN
# 997  sta Pereira email evangelista.pereira@thompson...        NaN
# 998             omolli email gareth.comolli@tiscali.fr        NaN
# 999      gelo Hess email michelangelo.hess@bouygtel.fr        NaN
#
# [1000 rows x 6 columns]
